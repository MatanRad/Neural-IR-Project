# %% [markdown]
# # Train our network
# ### Trains our network on pre-computed train data.
# ### Saves our network after each epoch.

# %%
import numpy as np
import os
import pacrr
import tensorflow as tf
import time
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
counter = 0

lq = 10
ld = 20
lf = 32
lg = 3
k = 3
lr = 0.01

saves_folder = r"D:\IRfiles\saves"
data_folder = r"D:\IRfiles\tdata"

# %%
# load network
yp, yn, prel, loss, opt, saver = pacrr.build(lq, ld, lf, lg, k=k, lr=lr)

# %%
# load epoch by epoch num (from pre-calculated epochs)
def load_epoch(counter):
    pathp = os.path.join(data_folder, "dp%d.npy" % counter)
    pathn = os.path.join(data_folder, "dn%d.npy" % counter)
    
    dp = np.load(pathp)
    dn = np.load(pathn)
    
    return dp, dn

# %%
def split_batches(a, batch_size):
    batches = []
    
    for i in range(int(a.shape[0]/batch_size)):
        batches.append(a[i*batch_size : (i+1) * batch_size])
    
    return batches

# %%
def train(dp, dn, sess, batch_size=32, print_every=0.25):
    dpb = split_batches(dp, batch_size)
    dnb = split_batches(dn, batch_size)
    
    if print_every < 1 and print_every > 0:
        print_every = int(np.floor(print_every * len(dpb)))
    
    batch_counter = 0
    for bp, bn in zip(dpb, dnb):
        feed_dict = { yp : bp, yn : bn }
        
        _, outls = sess.run([opt, loss], feed_dict=feed_dict)
        
        if print_every > 0 and batch_counter % print_every == 0:
            print("batch %d finished. loss: %f" % (batch_counter, np.sum(outls)))
        
        batch_counter += 1

# %%
# get mean loss of network
def get_loss(dp, dn, sess, batch_size=32):
    dpb = split_batches(dp, batch_size)
    dnb = split_batches(dn, batch_size)
    losses = []
    
    for bp, bn in zip(dpb, dnb):
        feed_dict = { yp : bp, yn : bn }
        
        outls = sess.run(loss, feed_dict=feed_dict)
        losses.append(outls)
        
    return np.mean(outls)

# %%
sess = None

# %%
# this is done for testing and debugging, if the session is already initialized, close it.
if sess is not None:
    sess.close()
    
sess = tf.Session()

# %%
# initialize TensorFlow variables.
var_inits = tf.global_variables_initializer()
sess.run(var_inits)

# %%
# train for 400 epochs (we stopped it early)
for i in range(400):
    print("starting epoch %d" % (counter))
    st = time.time()
    dp, dn = load_epoch(counter%203)
    train(dp, dn, sess, print_every=0, batch_size=128)
    
    meanloss = get_loss(dp, dn, sess)
    del dp
    del dn
    
    fpath = os.path.join(saves_folder, str(counter))
    if not os.path.isdir(fpath):
        os.mkdir(fpath)
    
    pacrr.save(sess, os.path.join(fpath, "e%d.cpt" % counter), saver)
    
    print("epoch finished. loss: %f. secs: %f" % (meanloss, time.time()-st))
    counter += 1
# Out:
# starting epoch 0
# epoch finished. loss: 0.472765. secs: 22.341220
# starting epoch 1
# epoch finished. loss: 0.473435. secs: 24.734217
# starting epoch 2
# epoch finished. loss: 0.472336. secs: 24.702677
# starting epoch 3
# epoch finished. loss: 0.471986. secs: 24.278812
# starting epoch 4
# epoch finished. loss: 0.472320. secs: 24.779385
# starting epoch 5
# epoch finished. loss: 0.466125. secs: 24.889526
# starting epoch 136
# epoch finished. loss: 0.474077. secs: 24.234500
# starting epoch 137
# epoch finished. loss: 0.474077. secs: 24.123279
# starting epoch 138
# epoch finished. loss: 0.474077. secs: 24.421013
# starting epoch 139
# epoch finished. loss: 0.474077. secs: 24.356209
# starting epoch 140
# epoch finished. loss: 0.474077. secs: 23.746572
# starting epoch 141
# epoch finished. loss: 0.474077. secs: 24.311888
# starting epoch 142
# epoch finished. loss: 0.474077. secs: 24.266421
# starting epoch 143
# epoch finished. loss: 0.474077. secs: 24.178398
# starting epoch 144
# epoch finished. loss: 0.474077. secs: 24.376699
# starting epoch 145
# epoch finished. loss: 0.474077. secs: 24.155411
# starting epoch 146
# epoch finished. loss: 0.474077. secs: 24.401637
# starting epoch 147
# epoch finished. loss: 0.474077. secs: 24.301066
# starting epoch 148
# epoch finished. loss: 0.474077. secs: 24.267980
# starting epoch 149
# epoch finished. loss: 0.474077. secs: 24.356307
# starting epoch 150
# epoch finished. loss: 0.474077. secs: 24.154552
# starting epoch 151
# epoch finished. loss: 0.474077. secs: 24.601785
# starting epoch 152
# epoch finished. loss: 0.474077. secs: 23.978678
# starting epoch 153
# epoch finished. loss: 0.474077. secs: 24.434414
# starting epoch 154
# epoch finished. loss: 0.474077. secs: 24.300903
# starting epoch 155
# epoch finished. loss: 0.474077. secs: 24.045246
# starting epoch 156
# epoch finished. loss: 0.474077. secs: 24.309383
# starting epoch 157
# epoch finished. loss: 0.474077. secs: 24.279464
# starting epoch 158
# epoch finished. loss: 0.474077. secs: 24.602245
# starting epoch 159
# epoch finished. loss: 0.474077. secs: 24.313548
# starting epoch 160
# epoch finished. loss: 0.474077. secs: 24.155068
# starting epoch 161
# epoch finished. loss: 0.474077. secs: 24.240512
# starting epoch 162
# epoch finished. loss: 0.474077. secs: 24.025030
# starting epoch 163
# epoch finished. loss: 0.474077. secs: 24.322609
# starting epoch 164
# epoch finished. loss: 0.474077. secs: 24.466646
# starting epoch 165
# epoch finished. loss: 0.474077. secs: 24.123981
# starting epoch 166
# epoch finished. loss: 0.474077. secs: 24.347890
# starting epoch 167
# epoch finished. loss: 0.474077. secs: 24.009337
# starting epoch 168
# epoch finished. loss: 0.474077. secs: 24.765970
# starting epoch 169
# epoch finished. loss: 0.474077. secs: 24.699713
# starting epoch 170
# epoch finished. loss: 0.474077. secs: 25.167159
# starting epoch 171
# epoch finished. loss: 0.474077. secs: 25.884531
# starting epoch 172
# epoch finished. loss: 0.474077. secs: 25.111321
# starting epoch 173
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-15e88814e436> in <module>()
#       5     train(dp, dn, sess, print_every=0, batch_size=128)
#       6
# ----> 7     meanloss = get_loss(dp, dn, sess)
#       8     del dp
#       9     del dn
#
# <ipython-input-7-d2ed5e71542c> in get_loss(dp, dn, sess, batch_size)
#       7         feed_dict = { yp : bp, yn : bn }
#       8
# ----> 9         outls = sess.run(loss, feed_dict=feed_dict)
#      10         losses.append(outls)
#      11
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
