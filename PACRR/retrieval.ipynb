# %% [markdown]
# # Retrieve Using PACRR
#
# ### This script's goal is to use our pre-trained model and pre-retrieved data using our simple classifier to re-rank and retrieve the best 5 results.

# %%
import dataset_loader as dl
import pacrr
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import gc
import time
import json
# Out:
# c:\python36\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
lq = 10
ld = 20
lf = 32
lg = 3
k = 3
lr = 0.01

raw_data_f = r"C:\Users\matan\Desktop\IR_Proj\data\anfL6.json"
token_data_f = "./tokenized_dataset.pickle"

netfile = r"D:\IRfiles\saves\250\e250.cpt"

qfile = "finalEval.txt"
outfile = "res.json"

# file as output from our Lucene classifier
from_answers_f = r"D:\IRfiles\irproj\data\res.json"

# %%
'''
Our train data is stored in a few ways:
all the raw_* arrays are just the dataset as is. not tokenization or answers/questions removed.
answers = an array of tokenized and w2v answers
qinds = an array of size len(answers). qinds[i] = index of question in questions to which answers[i] answers
questions = an array of tokenized and w2v questions.
'''

raw_ids, raw_questions, raw_answers, _ = dl.get_dataset(raw_data_f)
del _

ids, questions, answers, _ = dl.get_dataset_tokens_loaded(raw_data_f, token_data_f)
answers, qinds = dl.get_fixed_w2v_answers(answers, ld)

print("done")
# Out:
# done

# %%
gc.collect()

'''
because we store data differently (raw_answers is an array of size |raw_questions| of arrays of answers to each question) 
and our lucene IR system returns the answer via question_id and ans_ind we need to be able to convert from 
one representation to the other

<b>THIS IS FOR TRAINING AND FOR FINDING TEXT OF *ALREADY* RETRIEVED DOCUMENTS. RETRIEVAL IS DONE VIA THE NEURAL NET ONLY! </b>
'''

# from qind (index in the questions array) and aind (index of answer of that question in the original data.)
# returns index in answers array of corresponding answer.
def get_ans_ind(qind, aind):
    for i in range(len(qinds)):
        if qinds[i]==qind:
            return i + aind
    return None

# from qid (id of question) and aind (index of answer of that question in the original data.)
# returns index in answers array of corresponding answer.
def get_ans_ind_by_id(qid, aind):
    for i in range(len(qinds)):
        if ids[qinds[i]]==qid:
            return i + aind
    return None

# from ansind (index of answer in answers array)
# retuns index in questions and index of answer in that question in original data.
def ans_ind_to_q(ansind):
    questionind = qinds[ansind]
    i = ansind - 1
    firstqid = ansind
    while i >= 0 and qinds[i] == questionind:
        firstqid = i
        i -= 1
    return questionind, ansind - firstqid

# from ansind (index of answer in answers array)
# returns original text (non-tokenized) of answer from raw_answers
def ans_ind_to_text(ansind):
    qind, aind = ans_ind_to_q(ansind)
    qind = ids[qind]
    
    raw_qind = raw_ids.index(qind)
    return raw_answers[raw_qind][aind]

# %%
# load our trained network from file
sess = tf.Session()
loss, yp, yn, prel, opt, saver = pacrr.load(sess, netfile)
# Out:
# INFO:tensorflow:Restoring parameters from D:\IRfiles\saves\250\e250.cpt

# %%
# load questions file (finalEval.txt)
testids = []
with open(qfile, 'r') as f:
    lines = f.readlines()
for line in lines:
    testids.append(int(line[0:line.find("\t")]))

# %%
# convert from question ids to question indexes in questions array
testids = [ids.index(str(tid)) for tid in testids]

# %%
# splits data into batches for input to network
def split_batches(a, batch_size):
    batches = []
    
    for i in range(int(a.shape[0]/batch_size)):
        batches.append(a[i*batch_size : (i+1) * batch_size])
    
    return batches

# %%
# for each answer batch in answer_batches, give each similarity matrix a rank
def eval_q(answer_batches, batch_size=128):
    rankings = []
    for ab in answer_batches:
        feed_dict = { yp : ab }
        netout = sess.run(prel, feed_dict=feed_dict)
        rankings += netout.tolist()
    return rankings

# %%
# load our retrieved data for re-ranking (from our simple lucene system)
with open(from_answers_f, "r") as f:
    from_answers = json.load(f)

# %%
# for each question we now want to rank it with initial retrieval answers and return best ranked ones.

result = []

# how many should we return?
num_to_rank = 5

batch_size = 128
ans_counter = 0


for testqind in testids:
    st = time.time()
    
    #load question and change it to w2v
    q = questions[testqind][:]
    dl.to_w2v(q)
    q = dl.fix_length_single(q, lq)
    
    # find corresponding answers from retrieved data
    # (this is similar format to our json result. but instead of answer text we have original question id and ansind)
    # like previously explained in this code. (NOT USED FOR RETRIEVAL)    
    for jsonquestion in from_answers:
        if jsonquestion['id'] == ids[testqind]:
            my_answers = jsonquestion['answers']
            break
    
    # Pre-allocate space for similarity matrices
    sim_matrices = np.empty((len(my_answers), lq, ld))
    
    # Calculate matrices
    print("loading matrices")
    for idx, ans in enumerate(my_answers):
        sim_matrices[idx] = dl.get_cosine_mat(q, answers[get_ans_ind_by_id(ans['originId'], int(ans['index']))])
    
    batches = split_batches(sim_matrices, batch_size)
    
    # run through network
    print("evaling")
    output_ranking_vals = eval_q(batches)
    
    print("ranking")
    # find top ranked indexes (in net output)
    ranking = np.array(output_ranking_vals).argsort()[-num_to_rank:][::-1]
    curr_ranking = { "id" : str(ids[testqind])}
    
    # foreach index of top ranked results. Convert it's index from my_answers index to answers index and get original text.
    curr_answers = [{"answer" : ans_ind_to_text(get_ans_ind_by_id(my_answers[i]['originId'], int(my_answers[i]['index']))),
                     "score" : output_ranking_vals[i]} for i in ranking]
    
    curr_ranking["answers"] = curr_answers
    result.append(curr_ranking)
    print("question %d, ind %d, secs %d" % (ans_counter, testqind, time.time()-st))
    ans_counter += 1
    del q
    del sim_matrices
# Out:
# loading matrices
# evaling
# ranking
# question 0, ind 85295, secs 81
# loading matrices
# evaling
# ranking
# question 1, ind 13158, secs 81
# loading matrices
# evaling
# ranking
# question 2, ind 64616, secs 78
# loading matrices
# evaling
# ranking
# question 3, ind 30066, secs 83
# loading matrices
# evaling
# ranking
# question 4, ind 6135, secs 81
# loading matrices
# evaling
# ranking
# question 5, ind 10664, secs 78
# loading matrices
# evaling
# ranking
# question 6, ind 11702, secs 81
# loading matrices
# evaling
# ranking
# question 7, ind 42131, secs 82
# loading matrices
# evaling
# ranking
# question 8, ind 51489, secs 2
# loading matrices
# evaling
# ranking
# question 9, ind 70683, secs 81
# loading matrices
# evaling
# ranking
# question 10, ind 28407, secs 78
# loading matrices
# evaling
# ranking
# question 11, ind 63554, secs 81
# loading matrices
# evaling
# ranking
# question 12, ind 24619, secs 81
# loading matrices
# evaling
# ranking
# question 13, ind 41639, secs 84
# loading matrices
# evaling
# ranking
# question 14, ind 56697, secs 79
# loading matrices
# evaling
# ranking
# question 15, ind 7079, secs 80
# loading matrices
# evaling
# ranking
# question 16, ind 54210, secs 77
# loading matrices
# evaling
# ranking
# question 17, ind 21440, secs 76
# loading matrices
# evaling
# ranking
# question 18, ind 65007, secs 0
# loading matrices
# evaling
# ranking
# question 19, ind 85916, secs 80
# loading matrices
# evaling
# ranking
# question 20, ind 34941, secs 79
# loading matrices
# evaling
# ranking
# question 21, ind 13535, secs 79
# loading matrices
# evaling
# ranking
# question 22, ind 23466, secs 81
# loading matrices
# evaling
# ranking
# question 23, ind 73683, secs 80
# loading matrices
# evaling
# ranking
# question 24, ind 48138, secs 82
# loading matrices
# evaling
# ranking
# question 25, ind 4108, secs 81
# loading matrices
# evaling
# ranking
# question 26, ind 53681, secs 81
# loading matrices
# evaling
# ranking
# question 27, ind 70890, secs 80
# loading matrices
# evaling
# ranking
# question 28, ind 44069, secs 81
# loading matrices
# evaling
# ranking
# question 29, ind 48386, secs 82
# loading matrices
# evaling
# ranking
# question 30, ind 27022, secs 79
# loading matrices
# evaling
# ranking
# question 31, ind 3882, secs 80
# loading matrices
# evaling
# ranking
# question 32, ind 27590, secs 80
# loading matrices
# evaling
# ranking
# question 33, ind 27700, secs 0
# loading matrices
# evaling
# ranking
# question 34, ind 27742, secs 78
# loading matrices
# evaling
# ranking
# question 35, ind 49053, secs 79
# loading matrices
# evaling
# ranking
# question 36, ind 46434, secs 81
# loading matrices
# evaling
# ranking
# question 37, ind 24747, secs 80
# loading matrices
# evaling
# ranking
# question 38, ind 27745, secs 78
# loading matrices
# evaling
# ranking
# question 39, ind 48145, secs 82
# loading matrices
# evaling
# ranking
# question 40, ind 78227, secs 80
# loading matrices
# evaling
# ranking
# question 41, ind 39081, secs 81
# loading matrices
# evaling
# ranking
# question 42, ind 80295, secs 0
# loading matrices
# evaling
# ranking
# question 43, ind 79825, secs 82
# loading matrices
# evaling
# ranking
# question 44, ind 43638, secs 81
# loading matrices
# evaling
# ranking
# question 45, ind 7083, secs 82
# loading matrices
# evaling
# ranking
# question 46, ind 3679, secs 81
# loading matrices
# evaling
# ranking
# question 47, ind 6185, secs 79
# loading matrices
# evaling
# ranking
# question 48, ind 73769, secs 79
# loading matrices
# evaling
# ranking
# question 49, ind 67024, secs 4
# loading matrices
# evaling
# ranking
# question 50, ind 1201, secs 78
# loading matrices
# evaling
# ranking
# question 51, ind 80308, secs 78
# loading matrices
# evaling
# ranking
# question 52, ind 11939, secs 79
# loading matrices
# evaling
# ranking
# question 53, ind 25604, secs 79
# loading matrices
# evaling
# ranking
# question 54, ind 1984, secs 79
# loading matrices
# evaling
# ranking
# question 55, ind 5719, secs 80
# loading matrices
# evaling
# ranking
# question 56, ind 16787, secs 75
# loading matrices
# evaling
# ranking
# question 57, ind 73567, secs 80
# loading matrices
# evaling
# ranking
# question 58, ind 71004, secs 0
# loading matrices
# evaling
# ranking
# question 59, ind 27299, secs 79
# loading matrices
# evaling
# ranking
# question 60, ind 58585, secs 81
# loading matrices
# evaling
# ranking
# question 61, ind 53688, secs 83
# loading matrices
# evaling
# ranking
# question 62, ind 60007, secs 77
# loading matrices
# evaling
# ranking
# question 63, ind 52248, secs 79
# loading matrices
# evaling
# ranking
# question 64, ind 18925, secs 79
# loading matrices
# evaling
# ranking
# question 65, ind 10837, secs 81
# loading matrices
# evaling
# ranking
# question 66, ind 80814, secs 77
# loading matrices
# evaling
# ranking
# question 67, ind 78848, secs 0
# loading matrices
# evaling
# ranking
# question 68, ind 48008, secs 10
# loading matrices
# evaling
# ranking
# question 69, ind 57046, secs 79
# loading matrices
# evaling
# ranking
# question 70, ind 17886, secs 81
# loading matrices
# evaling
# ranking
# question 71, ind 5355, secs 78
# loading matrices
# evaling
# ranking
# question 72, ind 54441, secs 79
# loading matrices
# evaling
# ranking
# question 73, ind 17631, secs 83
# loading matrices
# evaling
# ranking
# question 74, ind 43899, secs 82
# loading matrices
# evaling
# ranking
# question 75, ind 8584, secs 79
# loading matrices
# evaling
# ranking
# question 76, ind 14586, secs 0
# loading matrices
# evaling
# ranking
# question 77, ind 59202, secs 80
# loading matrices
# evaling
# ranking
# question 78, ind 51369, secs 0
# loading matrices
# evaling
# ranking
# question 79, ind 63997, secs 80
# loading matrices
# evaling
# ranking
# question 80, ind 143, secs 81
# loading matrices
# evaling
# ranking
# question 81, ind 72228, secs 76
# loading matrices
# evaling
# ranking
# question 82, ind 31479, secs 81
# loading matrices
# evaling
# ranking
# question 83, ind 49657, secs 81
# loading matrices
# evaling
# ranking
# question 84, ind 65051, secs 46
# loading matrices
# evaling
# ranking
# question 85, ind 68396, secs 0
# loading matrices
# evaling
# ranking
# question 86, ind 70095, secs 82
# loading matrices
# evaling
# ranking
# question 87, ind 78315, secs 81
# loading matrices
# evaling
# ranking
# question 88, ind 16322, secs 81
# loading matrices
# evaling
# ranking
# question 89, ind 83965, secs 80
# loading matrices
# evaling
# ranking
# question 90, ind 48214, secs 83
# loading matrices
# evaling
# ranking
# question 91, ind 36931, secs 82
# loading matrices
# evaling
# ranking
# question 92, ind 55037, secs 80
# loading matrices
# evaling
# ranking
# question 93, ind 19026, secs 81
# loading matrices
# evaling
# ranking
# question 94, ind 5244, secs 83
# loading matrices
# evaling
# ranking
# question 95, ind 52073, secs 0
# loading matrices
# evaling
# ranking
# question 96, ind 1168, secs 77
# loading matrices
# evaling
# ranking
# question 97, ind 31267, secs 60
# loading matrices
# evaling
# ranking
# question 98, ind 7746, secs 81
# loading matrices
# evaling
# ranking
# question 99, ind 4043, secs 78
# loading matrices
# evaling
# ranking
# question 100, ind 2687, secs 0
# loading matrices
# evaling
# ranking
# question 101, ind 70215, secs 80
# loading matrices
# evaling
# ranking
# question 102, ind 50346, secs 80
# loading matrices
# evaling
# ranking
# question 103, ind 24022, secs 82
# loading matrices
# evaling
# ranking
# question 104, ind 38720, secs 78
# loading matrices
# evaling
# ranking
# question 105, ind 47166, secs 77
# loading matrices
# evaling
# ranking
# question 106, ind 20843, secs 75
# loading matrices
# evaling
# ranking
# question 107, ind 11100, secs 76
# loading matrices
# evaling
# ranking
# question 108, ind 1208, secs 81
# loading matrices
# evaling
# ranking
# question 109, ind 52099, secs 82
# loading matrices
# evaling
# ranking
# question 110, ind 83827, secs 81
# loading matrices
# evaling
# ranking
# question 111, ind 74833, secs 81
# loading matrices
# evaling
# ranking
# question 112, ind 21862, secs 81
# loading matrices
# evaling
# ranking
# question 113, ind 37739, secs 78
# loading matrices
# evaling
# ranking
# question 114, ind 36355, secs 78
# loading matrices
# evaling
# ranking
# question 115, ind 61292, secs 76
# loading matrices
# evaling
# ranking
# question 116, ind 11032, secs 79
# loading matrices
# evaling
# ranking
# question 117, ind 77651, secs 82
# loading matrices
# evaling
# ranking
# question 118, ind 29863, secs 79
# loading matrices
# evaling
# ranking
# question 119, ind 86966, secs 80
# loading matrices
# evaling
# ranking
# question 120, ind 77132, secs 0
# loading matrices
# evaling
# ranking
# question 121, ind 19479, secs 79
# loading matrices
# evaling
# ranking
# question 122, ind 48922, secs 77
# loading matrices
# evaling
# ranking
# question 123, ind 3549, secs 81
# loading matrices
# evaling
# ranking
# question 124, ind 77746, secs 77
# loading matrices
# evaling
# ranking
# question 125, ind 40327, secs 79
# loading matrices
# evaling
# ranking
# question 126, ind 27977, secs 78
# loading matrices
# evaling
# ranking
# question 127, ind 66548, secs 82
# loading matrices
# evaling
# ranking
# question 128, ind 12880, secs 80
# loading matrices
# evaling
# ranking
# question 129, ind 79408, secs 81
# loading matrices
# evaling
# ranking
# question 130, ind 85323, secs 82
# loading matrices
# evaling
# ranking
# question 131, ind 75850, secs 84
# loading matrices
# evaling
# ranking
# question 132, ind 71626, secs 0
# loading matrices
# evaling
# ranking
# question 133, ind 3831, secs 79
# loading matrices
# evaling
# ranking
# question 134, ind 73306, secs 78
# loading matrices
# evaling
# ranking
# question 135, ind 54020, secs 77
# loading matrices
# evaling
# ranking
# question 136, ind 78297, secs 84
# loading matrices
# evaling
# ranking
# question 137, ind 35739, secs 0
# loading matrices
# evaling
# ranking
# question 138, ind 51620, secs 81
# loading matrices
# evaling
# ranking
# question 139, ind 4654, secs 77
# loading matrices
# evaling
# ranking
# question 140, ind 86446, secs 82
# loading matrices
# evaling
# ranking
# question 141, ind 61931, secs 80
# loading matrices
# evaling
# ranking
# question 142, ind 77232, secs 78
# loading matrices
# evaling
# ranking
# question 143, ind 57538, secs 78
# loading matrices
# evaling
# ranking
# question 144, ind 70586, secs 81
# loading matrices
# evaling
# ranking
# question 145, ind 74204, secs 80
# loading matrices
# evaling
# ranking
# question 146, ind 15939, secs 79
# loading matrices
# evaling
# ranking
# question 147, ind 28574, secs 78
# loading matrices
# evaling
# ranking
# question 148, ind 7630, secs 81
# loading matrices
# evaling
# ranking
# question 149, ind 26892, secs 80
# loading matrices
# evaling
# ranking
# question 150, ind 9204, secs 80
# loading matrices
# evaling
# ranking
# question 151, ind 26589, secs 81
# loading matrices
# evaling
# ranking
# question 152, ind 67085, secs 81
# loading matrices
# evaling
# ranking
# question 153, ind 56851, secs 12
# loading matrices
# evaling
# ranking
# question 154, ind 13907, secs 75
# loading matrices
# evaling
# ranking
# question 155, ind 916, secs 81
# loading matrices
# evaling
# ranking
# question 156, ind 39693, secs 80
# loading matrices
# evaling
# ranking
# question 157, ind 982, secs 80
# loading matrices
# evaling
# ranking
# question 158, ind 40849, secs 78
# loading matrices
# evaling
# ranking
# question 159, ind 51300, secs 79
# loading matrices
# evaling
# ranking
# question 160, ind 37823, secs 84
# loading matrices
# evaling
# ranking
# question 161, ind 79609, secs 74
# loading matrices
# evaling
# ranking
# question 162, ind 38337, secs 81
# loading matrices
# evaling
# ranking
# question 163, ind 7648, secs 85
# loading matrices
# evaling
# ranking
# question 164, ind 17146, secs 0
# loading matrices
# evaling
# ranking
# question 165, ind 63860, secs 79
# loading matrices
# evaling
# ranking
# question 166, ind 46169, secs 79
# loading matrices
# evaling
# ranking
# question 167, ind 42991, secs 84
# loading matrices
# evaling
# ranking
# question 168, ind 69354, secs 82
# loading matrices
# evaling
# ranking
# question 169, ind 18311, secs 79
# loading matrices
# evaling
# ranking
# question 170, ind 24611, secs 78
# loading matrices
# evaling
# ranking
# question 171, ind 83658, secs 77
# loading matrices
# evaling
# ranking
# question 172, ind 74221, secs 81
# loading matrices
# evaling
# ranking
# question 173, ind 54823, secs 46
# loading matrices
# evaling
# ranking
# question 174, ind 57428, secs 80
# loading matrices
# evaling
# ranking
# question 175, ind 15700, secs 78
# loading matrices
# evaling
# ranking
# question 176, ind 61083, secs 77
# loading matrices
# evaling
# ranking
# question 177, ind 60166, secs 82
# loading matrices
# evaling
# ranking
# question 178, ind 24974, secs 84
# loading matrices
# evaling
# ranking
# question 179, ind 77179, secs 78
# loading matrices
# evaling
# ranking
# question 180, ind 74365, secs 82
# loading matrices
# evaling
# ranking
# question 181, ind 73152, secs 81
# loading matrices
# evaling
# ranking
# question 182, ind 53298, secs 81
# loading matrices
# evaling
# ranking
# question 183, ind 61918, secs 81
# loading matrices
# evaling
# ranking
# question 184, ind 27762, secs 78
# loading matrices
# evaling
# ranking
# question 185, ind 53058, secs 78
# loading matrices
# evaling
# ranking
# question 186, ind 32662, secs 79
# loading matrices
# evaling
# ranking
# question 187, ind 27217, secs 81
# loading matrices
# evaling
# ranking
# question 188, ind 5188, secs 81
# loading matrices
# evaling
# ranking
# question 189, ind 44000, secs 79
# loading matrices
# evaling
# ranking
# question 190, ind 56918, secs 78
# loading matrices
# evaling
# ranking
# question 191, ind 68105, secs 78
# loading matrices
# evaling
# ranking
# question 192, ind 18743, secs 77
# loading matrices
# evaling
# ranking
# question 193, ind 12936, secs 81
# loading matrices
# evaling
# ranking
# question 194, ind 17593, secs 76
# loading matrices
# evaling
# ranking
# question 195, ind 54974, secs 2
# loading matrices
# evaling
# ranking
# question 196, ind 30550, secs 79
# loading matrices
# evaling
# ranking
# question 197, ind 40099, secs 81
# loading matrices
# evaling
# ranking
# question 198, ind 63457, secs 80
# loading matrices
# evaling
# ranking
# question 199, ind 401, secs 77
# loading matrices
# evaling
# ranking
# question 200, ind 81036, secs 83
# loading matrices
# evaling
# ranking
# question 201, ind 26237, secs 80
# loading matrices
# evaling
# ranking
# question 202, ind 76144, secs 79
# loading matrices
# evaling
# ranking
# question 203, ind 80580, secs 79
# loading matrices
# evaling
# ranking
# question 204, ind 12457, secs 79
# loading matrices
# evaling
# ranking
# question 205, ind 4925, secs 78
# loading matrices
# evaling
# ranking
# question 206, ind 32289, secs 82
# loading matrices
# evaling
# ranking
# question 207, ind 85226, secs 78
# loading matrices
# evaling
# ranking
# question 208, ind 38746, secs 80
# loading matrices
# evaling
# ranking
# question 209, ind 47952, secs 84
# loading matrices
# evaling
# ranking
# question 210, ind 71590, secs 82
# loading matrices
# evaling
# ranking
# question 211, ind 22950, secs 81
# loading matrices
# evaling
# ranking
# question 212, ind 36617, secs 77
# loading matrices
# evaling
# ranking
# question 213, ind 82893, secs 79
# loading matrices
# evaling
# ranking
# question 214, ind 54929, secs 81
# loading matrices
# evaling
# ranking
# question 215, ind 59988, secs 18
# loading matrices
# evaling
# ranking
# question 216, ind 54256, secs 81
# loading matrices
# evaling
# ranking
# question 217, ind 27274, secs 77
# loading matrices
# evaling
# ranking
# question 218, ind 52354, secs 0
# loading matrices
# evaling
# ranking
# question 219, ind 27176, secs 78
# loading matrices
# evaling
# ranking
# question 220, ind 17808, secs 81
# loading matrices
# evaling
# ranking
# question 221, ind 80431, secs 80
# loading matrices
# evaling
# ranking
# question 222, ind 31420, secs 80
# loading matrices
# evaling
# ranking
# question 223, ind 14223, secs 78
# loading matrices
# evaling
# ranking
# question 224, ind 30966, secs 80
# loading matrices
# evaling
# ranking
# question 225, ind 74018, secs 79
# loading matrices
# evaling
# ranking
# question 226, ind 25480, secs 79
# loading matrices
# evaling
# ranking
# question 227, ind 72285, secs 79
# loading matrices
# evaling
# ranking
# question 228, ind 41304, secs 83
# loading matrices
# evaling
# ranking
# question 229, ind 66039, secs 79
# loading matrices
# evaling
# ranking
# question 230, ind 44883, secs 39
# loading matrices
# evaling
# ranking
# question 231, ind 3252, secs 83
# loading matrices
# evaling
# ranking
# question 232, ind 72976, secs 89
# loading matrices
# evaling
# ranking
# question 233, ind 76372, secs 79
# loading matrices
# evaling
# ranking
# question 234, ind 34493, secs 84
# loading matrices
# evaling
# ranking
# question 235, ind 57982, secs 82
# loading matrices
# evaling
# ranking
# question 236, ind 12694, secs 82
# loading matrices
# evaling
# ranking
# question 237, ind 81077, secs 81
# loading matrices
# evaling
# ranking
# question 238, ind 82336, secs 0
# loading matrices
# evaling
# ranking
# question 239, ind 41257, secs 77
# loading matrices
# evaling
# ranking
# question 240, ind 6717, secs 78
# loading matrices
# evaling
# ranking
# question 241, ind 72372, secs 80
# loading matrices
# evaling
# ranking
# question 242, ind 945, secs 79
# loading matrices
# evaling
# ranking
# question 243, ind 81444, secs 78
# loading matrices
# evaling
# ranking
# question 244, ind 32478, secs 84
# loading matrices
# evaling
# ranking
# question 245, ind 59068, secs 0
# loading matrices
# evaling
# ranking
# question 246, ind 70098, secs 82
# loading matrices
# evaling
# ranking
# question 247, ind 71673, secs 83
# loading matrices
# evaling
# ranking
# question 248, ind 6393, secs 88
# loading matrices
# evaling
# ranking
# question 249, ind 85990, secs 4
# loading matrices
# evaling
# ranking
# question 250, ind 13238, secs 82
# loading matrices
# evaling
# ranking
# question 251, ind 54019, secs 88
# loading matrices
# evaling
# ranking
# question 252, ind 24966, secs 0
# loading matrices
# evaling
# ranking
# question 253, ind 13245, secs 82
# loading matrices
# evaling
# ranking
# question 254, ind 5846, secs 84
# loading matrices
# evaling
# ranking
# question 255, ind 50631, secs 89
# loading matrices
# evaling
# ranking
# question 256, ind 845, secs 87
# loading matrices
# evaling
# ranking
# question 257, ind 4685, secs 3
# loading matrices
# evaling
# ranking
# question 258, ind 8677, secs 85
# loading matrices
# evaling
# ranking
# question 259, ind 30798, secs 85
# loading matrices
# evaling
# ranking
# question 260, ind 31078, secs 87
# loading matrices
# evaling
# ranking
# question 261, ind 39820, secs 87
# loading matrices
# evaling
# ranking
# question 262, ind 79523, secs 86
# loading matrices
# evaling
# ranking
# question 263, ind 30219, secs 57
# loading matrices
# evaling
# ranking
# question 264, ind 34939, secs 86
# loading matrices
# evaling
# ranking
# question 265, ind 66436, secs 84
# loading matrices
# evaling
# ranking
# question 266, ind 87212, secs 85
# loading matrices
# evaling
# ranking
# question 267, ind 37962, secs 86
# loading matrices
# evaling
# ranking
# question 268, ind 81174, secs 89
# loading matrices
# evaling
# ranking
# question 269, ind 60566, secs 98
# loading matrices
# evaling
# ranking
# question 270, ind 52209, secs 98
# loading matrices
# evaling
# ranking
# question 271, ind 37241, secs 97
# loading matrices
# evaling
# ranking
# question 272, ind 23462, secs 96
# loading matrices
# evaling
# ranking
# question 273, ind 21187, secs 0
# loading matrices
# evaling
# ranking
# question 274, ind 49617, secs 98
# loading matrices
# evaling
# ranking
# question 275, ind 36124, secs 94
# loading matrices
# evaling
# ranking
# question 276, ind 16201, secs 48
# loading matrices
# evaling
# ranking
# question 277, ind 15593, secs 97
# loading matrices
# evaling
# ranking
# question 278, ind 25315, secs 96
# loading matrices
# evaling
# ranking
# question 279, ind 39061, secs 93
# loading matrices
# evaling
# ranking
# question 280, ind 32667, secs 89
# loading matrices
# evaling
# ranking
# question 281, ind 34080, secs 81
# loading matrices
# evaling
# ranking
# question 282, ind 47860, secs 82
# loading matrices
# evaling
# ranking
# question 283, ind 6014, secs 83
# loading matrices
# evaling
# ranking
# question 284, ind 11827, secs 41
# loading matrices
# evaling
# ranking
# question 285, ind 70975, secs 79
# loading matrices
# evaling
# ranking
# question 286, ind 72583, secs 81
# loading matrices
# evaling
# ranking
# question 287, ind 8164, secs 78
# loading matrices
# evaling
# ranking
# question 288, ind 79752, secs 83
# loading matrices
# evaling
# ranking
# question 289, ind 12114, secs 86
# loading matrices
# evaling
# ranking
# question 290, ind 70831, secs 86
# loading matrices
# evaling
# ranking
# question 291, ind 81393, secs 91
# loading matrices
# evaling
# ranking
# question 292, ind 40024, secs 93
# loading matrices
# evaling
# ranking
# question 293, ind 65119, secs 91
# loading matrices
# evaling
# ranking
# question 294, ind 26933, secs 95
# loading matrices
# evaling
# ranking
# question 295, ind 20560, secs 92
# loading matrices
# evaling
# ranking
# question 296, ind 2593, secs 91
# loading matrices
# evaling
# ranking
# question 297, ind 23590, secs 91
# loading matrices
# evaling
# ranking
# question 298, ind 73249, secs 94
# loading matrices
# evaling
# ranking
# question 299, ind 27715, secs 0

# %%
# write to json file (final result before submitting)
with open(outfile, 'w', encoding="ascii") as f:
    json.dump(result, f, indent=4)
